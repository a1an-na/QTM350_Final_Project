# %%
desc_stats = df_clean.groupby("country")[[
    "life_expectancy", "under5_mortality", "adolescent_fertility"
]].describe().round(2)

import pandas as pd
pd.set_option('display.max_columns', None)
desc_stats
# Out:
#                life_expectancy                                           \
#                          count   mean   std    min    25%    50%    75%
# country
# Afghanistan               24.0  60.49  2.88  55.00  58.48  60.98  62.30
# Brazil                    24.0  73.44  1.92  69.58  72.18  73.91  74.92
# India                     24.0  67.45  2.76  62.75  65.26  67.45  69.80
# Kenya                     24.0  60.53  2.32  56.08  58.92  61.25  62.34
# United Kingdom            24.0  80.09  1.20  77.74  79.20  80.52  81.05
#
#                       under5_mortality                                    \
#                   max            count   mean    std   min    25%    50%
# country
# Afghanistan     66.04             24.0  87.44  24.03  55.5  67.05  82.90
# Brazil          75.85             24.0  20.18   6.07  14.4  15.35  17.55
# India           72.00             24.0  55.70  20.25  27.7  38.12  53.50
# Kenya           63.65             24.0  58.16  17.18  39.9  45.05  51.70
# ...
